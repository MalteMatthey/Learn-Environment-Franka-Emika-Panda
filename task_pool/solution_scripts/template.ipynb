# %% [markdown]
# # Educational Plattform Panda Robot
# Author: uninh, uqwfa, ultck

# %% [markdown]
# ## Topic_Name
# ### Exercise_X
#
# ---
# > In this task, you will learn ...
# >
# > - ...
# > - ...
#
# ---

# %% [markdown]
# Code cell that the students should not change.

# %%
##### DO NOT CHANGE #####



##### DO NOT CHANGE #####

# %% [markdown]
# This is a markdown cell describing the users what to implement and has a code cell underneath.
#
# ToDo:
# - implement1
# - implemnt2

# %%
##### YOUR CODE HERE #####



##### YOUR CODE HERE #####
